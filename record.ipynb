# %% [markdown]
# # 1 LSTM / LSTM + CRF

# %% [markdown]
# 分别使用**LSTM 和 LSTM + CRF** 进行NER任务，对比实验结果

# %% [markdown]
# ## 1.1 python main.py --model lstm

# %%
 # 20 epochs LSTM
val_loss = [0.9206,0.4801,0.3491,0.2747,0.2266,0.1938,0.1740,0.1628,0.1530,0.1454,0.1418,0.1394,0.1366,0.1395,0.1489,0.1488,0.1377,0.1268,0.1320,0.1322]

# %%
训练完毕,共用时524秒.
评估lstm模型中...
           precision    recall  f1-score   support
  M-TITLE     0.9373    0.8793    0.9074      1922
   E-NAME     0.9905    0.9286    0.9585       112
  B-TITLE     0.9263    0.9275    0.9269       772
    B-ORG     0.9526    0.9439    0.9482       553
    E-ORG     0.9242    0.9042    0.9141       553
   M-NAME     0.9146    0.9146    0.9146        82
        O     0.9667    0.9844    0.9755      5897
   B-NAME     0.9896    0.8482    0.9135       112
    M-ORG     0.9532    0.9649    0.9590      4325
  E-TITLE     0.9883    0.9845    0.9864       772
label_level   0.9561    0.9563    0.9560     15100
    TITLE     0.9448    0.9093    0.9267       772
     NAME     0.9895    0.8393    0.9082       112
      ORG     0.9167    0.8553    0.8849       553
  all_ent     0.9372    0.8831    0.9094      1437

# %% [markdown]
# ## 1.2 python main.py --model lstm --crf

# %% [markdown]
# 添加CRF层

# %%
# 20 epochs
val_loss = [24.5129,13.8706,9.8104,7.5413,6.2182,5.4467,5.0032,4.7575,4.5993,4.3771,4.2221,4.1334,4.3227,4.3225,4.1802,4.3641,4.3730,4.3047,4.2800,4.4624]

# %%
训练完毕,共用时697秒.
评估lstm+CRF模型中...
           precision    recall  f1-score   support
  B-TITLE     0.9420    0.9249    0.9333       772
   M-NAME     0.9186    0.9634    0.9405        82
    M-ORG     0.9496    0.9672    0.9583      4325
   E-NAME     0.9907    0.9554    0.9727       112
   B-NAME     1.0000    0.8661    0.9282       112
        O     0.9655    0.9737    0.9696      5897
  M-TITLE     0.9396    0.8902    0.9142      1922
    B-ORG     0.9568    0.9602    0.9585       553
  E-TITLE     0.9806    0.9832    0.9819       772
    E-ORG     0.9308    0.9241    0.9274       553
label_level     0.9558    0.9559    0.9557     15100
    TITLE     0.9491    0.9171    0.9328       772
      ORG     0.9360    0.8987    0.9170       553
     NAME     1.0000    0.8661    0.9282       112
  all_ent     0.9476    0.9061    0.9264      1437

# %%
# 20 epochs LSTM
val_loss1 = [0.9206,0.4801,0.3491,0.2747,0.2266,0.1938,0.1740,0.1628,0.1530,0.1454,0.1418,0.1394,0.1366,0.1395,0.1489,0.1488,0.1377,0.1268,0.1320,0.1322]
# 20 epochs LSTM + CRF
val_loss2 = [24.5129,13.8706,9.8104,7.5413,6.2182,5.4467,5.0032,4.7575,4.5993,4.3771,4.2221,4.1334,4.3227,4.3225,4.1802,4.3641,4.3730,4.3047,4.2800,4.4624]
import matplotlib.pyplot as plt
from pylab import *
from decimal import Decimal 
epochs = range(1, len(val_loss1) + 1)

plt.figure(figsize=(24,17))
plt.plot(epochs, val_loss1, marker = 'o',label = 'Validation loss -- LSTM', markersize = 15,linewidth = 3.7)
plt.plot(epochs, val_loss2, marker = 'o', label = 'Validation loss -- LSTM-CRF', markersize = 16,linewidth = 3.7)

x_major_locator = MultipleLocator(1)
y_major_locator = MultipleLocator(5)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
#plt.annotate(Decimal(train_loss[19]).quantize(Decimal('0.00')), xy = (20,train_loss[19]), fontsize = 37, xytext=(19.3,train_loss[19] + 0.05))
#plt.annotate(Decimal(dev_loss[19]).quantize(Decimal('0.00')), xy = (20,dev_loss[19]), fontsize = 37, xytext=(19.3,dev_loss[19] - 0.10))
plt.tick_params(axis = 'both', which = 'major', labelsize = 29)
plt.tick_params(axis = 'x', which = 'major', labelsize = 33)
plt.xlim(0.5,20.5)
plt.ylim(0,25)

plt.title('Validation Loss', fontsize = 45)
plt.xlabel('Epochs',fontsize = 38)
plt.ylabel('Loss', fontsize = 38)
# minorticks_on()
plt.grid()
plt.legend(loc = 1, prop = {'size' : 35})
plt.show()

# %% [markdown]
# # 2 BiLSTM / BiLSTM + CRF

# %% [markdown]
# 分别使用**BiLSTM 和 BiLSTM + CRF** 进行NER任务，对比实验结果

# %% [markdown]
# ## 2.1 python main.py --model bilstm

# %%
# 20 epochs BILSTM
val_loss = [0.8716,0.4552,0.3311,0.2640,0.2226,0.1967,0.1812,0.1711,0.1653,0.1589,0.1619,0.1642,0.1646,0.1564,0.1562,0.1656,0.1648,0.1569,0.1656,0.1586]

# %%
训练完毕,共用时547秒.
评估bilstm模型中...
           precision    recall  f1-score   support
        O     0.9560    0.9847    0.9702      5897
    M-ORG     0.9627    0.9540    0.9583      4325
    E-ORG     0.9463    0.8915    0.9181       553
   E-NAME     0.9906    0.9375    0.9633       112
  B-TITLE     0.9476    0.9132    0.9301       772
   B-NAME     0.9899    0.8750    0.9289       112
   M-NAME     0.9390    0.9390    0.9390        82
  E-TITLE     0.9781    0.9832    0.9806       772
    B-ORG     0.9669    0.9512    0.9590       553
  M-TITLE     0.9234    0.8975    0.9103      1922
label_level   0.9549    0.9550    0.9548     15100
    TITLE     0.9547    0.9003    0.9267       772
      ORG     0.9435    0.8463    0.8923       553
     NAME     1.0000    0.8750    0.9333       112
  all_ent     0.9539    0.8775    0.9141      1437

# %% [markdown]
# ## 2.2 python main.py --model bilstm --crf

# %%
# 20 epochs BiLSTM - CRF
val_loss = [23.3360, 13.6036,9.3042,7.1679,6.1044,5.4149,5.0037,4.7799,4.7443,4.5241,4.2553,4.1024,4.0937,4.0105,4.2080,4.1787,4.1259,4.1931,4.6001,4.5045]

# %%
训练完毕,共用时701秒.
评估bilstm+CRF模型中...
           precision    recall  f1-score   support
    M-ORG     0.9572    0.9623    0.9598      4325
    B-ORG     0.9793    0.9403    0.9594       553
    E-ORG     0.9122    0.9204    0.9163       553
   B-NAME     0.9703    0.8750    0.9202       112
   M-NAME     0.9487    0.9024    0.9250        82
   E-NAME     1.0000    0.9018    0.9484       112
  M-TITLE     0.9553    0.8902    0.9216      1922
        O     0.9535    0.9800    0.9665      5897
  B-TITLE     0.9363    0.9326    0.9345       772
  E-TITLE     0.9882    0.9754    0.9817       772
label_level     0.9556    0.9554    0.9552     15100
      ORG     0.9349    0.8825    0.9079       553
     NAME     1.0000    0.8482    0.9179       112
    TITLE     0.9491    0.9171    0.9328       772
  all_ent     0.9472    0.8984    0.9221      1437

# %%
# 20 epochs Bilstm
val_loss1 = [0.8716,0.4552,0.3311,0.2640,0.2226,0.1967,0.1812,0.1711,0.1653,0.1589,0.1619,0.1642,0.1646,0.1564,0.1562,0.1656,0.1648,0.1569,0.1656,0.1586]
# 20 epochs Bilstm CRF
val_loss2 = [23.3360, 13.6036,9.3042,7.1679,6.1044,5.4149,5.0037,4.7799,4.7443,4.5241,4.2553,4.1024,4.0937,4.0105,4.2080,4.1787,4.1259,4.1931,4.6001,4.5045]
import matplotlib.pyplot as plt
from pylab import *
from decimal import Decimal 
epochs = range(1, len(val_loss1) + 1)

plt.figure(figsize=(24,19))
plt.plot(epochs, val_loss1, marker = 'o',label = 'Validation loss -- BiLSTM', markersize = 15,linewidth = 3.7)
plt.plot(epochs, val_loss2, marker = 'o', label = 'Validation loss -- BiLSTM-CRF', markersize = 16,linewidth = 3.7)

x_major_locator = MultipleLocator(1)
y_major_locator = MultipleLocator(5)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
#plt.annotate(Decimal(train_loss[19]).quantize(Decimal('0.00')), xy = (20,train_loss[19]), fontsize = 37, xytext=(19.3,train_loss[19] + 0.05))
#plt.annotate(Decimal(dev_loss[19]).quantize(Decimal('0.00')), xy = (20,dev_loss[19]), fontsize = 37, xytext=(19.3,dev_loss[19] - 0.10))
plt.tick_params(axis = 'both', which = 'major', labelsize = 29)
plt.tick_params(axis = 'x', which = 'major', labelsize = 33)
plt.xlim(0.5,20.5)
plt.ylim(0,25)

plt.title('Validation Loss', fontsize = 45)
plt.xlabel('Epochs',fontsize = 38)
plt.ylabel('Loss', fontsize = 38)
# minorticks_on()
plt.grid()
plt.legend(loc = 1, prop = {'size' : 35})
plt.show()

# %% [markdown]
# # 3 CNN / CNN + CRF

# %% [markdown]
# 分别使用**CNN 和 CNN + CRF** 进行NER任务，对比实验结果

# %% [markdown]
# ## 3.1 python main.py --model cnn

# %%
# 20 epochs CNN
val_loss = [0.6789,0.4498,0.3547,0.3057,0.2699,0.2567,0.2500,0.2385,0.2375,0.2335,0.2352,0.2328,0.2360,0.2297,0.2280,0.2293,0.2271,0.2263,0.2296,0.2293]

# %%
训练完毕,共用时72秒.
评估cnn模型中...
           precision    recall  f1-score   support
   M-NAME     0.8916    0.9024    0.8970        82
    B-ORG     0.9186    0.9186    0.9186       553
  B-TITLE     0.8982    0.9145    0.9063       772
   E-NAME     0.9545    0.9375    0.9459       112
   B-NAME     0.8812    0.7946    0.8357       112
    E-ORG     0.8488    0.9241    0.8848       553
  E-TITLE     0.9782    0.9896    0.9839       772
        O     0.9448    0.9454    0.9451      5897
    M-ORG     0.9359    0.9147    0.9252      4325
  M-TITLE     0.8671    0.8824    0.8747      1922
label_level   0.9265    0.9261    0.9262     15100
    TITLE     0.9496    0.8782    0.9125       772
     NAME     0.9888    0.7857    0.8756       112
      ORG     0.8226    0.6962    0.7542       553
  all_ent     0.9056    0.8010    0.8501      1437

# %% [markdown]
# ## 3.3 python main.py --model cnn --crf

# %%
# 20 epochs CNN-CRF
val_loss = [18.2195,12.7704,10.2930,8.9603,8.0248,7.3808,6.9796,6.6189,6.4273,6.1760,5.9981,5.8655,5.6707,5.6030,5.4614,5.3432,5.2548,5.1576,5.0078,4.9809]

# %%
训练完毕,共用时216秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
    E-ORG     0.9055    0.9186    0.9120       553
        O     0.9491    0.9495    0.9493      5897
  M-TITLE     0.9233    0.8959    0.9094      1922
  E-TITLE     0.9883    0.9883    0.9883       772
   M-NAME     0.9146    0.9146    0.9146        82
  B-TITLE     0.9168    0.9275    0.9221       772
    M-ORG     0.9342    0.9447    0.9394      4325
   E-NAME     0.9712    0.9018    0.9352       112
   B-NAME     0.8585    0.8125    0.8349       112
    B-ORG     0.9263    0.9313    0.9288       553
label_level   0.9388    0.9388    0.9387     15100
      ORG     0.9177    0.8065    0.8585       553
    TITLE     0.9562    0.9054    0.9301       772
     NAME     1.0000    0.8036    0.8911       112
  all_ent     0.9449    0.8594    0.9001      1437

# %%
# 20 epochs CNN
val_loss1 = [0.6789,0.4498,0.3547,0.3057,0.2699,0.2567,0.2500,0.2385,0.2375,0.2335,0.2352,0.2328,0.2360,0.2297,0.2280,0.2293,0.2271,0.2263,0.2296,0.2293]

# 20 epochs CNN CRF
val_loss2 = [18.2195,12.7704,10.2930,8.9603,8.0248,7.3808,6.9796,6.6189,6.4273,6.1760,5.9981,5.8655,5.6707,5.6030,5.4614,5.3432,5.2548,5.1576,5.0078,4.9809]
import matplotlib.pyplot as plt
from pylab import *
from decimal import Decimal 
epochs = range(1, len(val_loss1) + 1)

plt.figure(figsize=(24,19))
plt.plot(epochs, val_loss1, marker = 'o',label = 'Validation loss -- CNN', markersize = 15,linewidth = 3.7)
plt.plot(epochs, val_loss2, marker = 'o', label = 'Validation loss -- CNN-CRF', markersize = 16,linewidth = 3.7)

x_major_locator = MultipleLocator(1)
y_major_locator = MultipleLocator(5)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
#plt.annotate(Decimal(train_loss[19]).quantize(Decimal('0.00')), xy = (20,train_loss[19]), fontsize = 37, xytext=(19.3,train_loss[19] + 0.05))
#plt.annotate(Decimal(dev_loss[19]).quantize(Decimal('0.00')), xy = (20,dev_loss[19]), fontsize = 37, xytext=(19.3,dev_loss[19] - 0.10))
plt.tick_params(axis = 'both', which = 'major', labelsize = 29)
plt.tick_params(axis = 'x', which = 'major', labelsize = 33)
plt.xlim(0.5,20.5)
plt.ylim(0,25)

plt.title('Validation Loss', fontsize = 45)
plt.xlabel('Epochs',fontsize = 38)
plt.ylabel('Loss', fontsize = 38)
# minorticks_on()
plt.grid()
plt.legend(loc = 1, prop = {'size' : 35})
plt.show()

# %%
# 20 epochs LSTM - CRF
val_loss1 = [24.5129,13.8706,9.8104,7.5413,6.2182,5.4467,5.0032,4.7575,4.5993,4.3771,4.2221,4.1334,4.3227,4.3225,4.1802,4.3641,4.3730,4.3047,4.2800,4.4624]
# 20 epochs BiLSTM - CRF
val_loss2 = [23.3360, 13.6036,9.3042,7.1679,6.1044,5.4149,5.0037,4.7799,4.7443,4.5241,4.2553,4.1024,4.0937,4.0105,4.2080,4.1787,4.1259,4.1931,4.6001,4.5045]
# 20 epochs CNN - CRF
val_loss3 = [18.2195,12.7704,10.2930,8.9603,8.0248,7.3808,6.9796,6.6189,6.4273,6.1760,5.9981,5.8655,5.6707,5.6030,5.4614,5.3432,5.2548,5.1576,5.0078,4.9809]


import matplotlib.pyplot as plt
from pylab import *
from decimal import Decimal 
epochs = range(1, len(val_loss1) + 1)

plt.figure(figsize=(24,21))
plt.plot(epochs, val_loss1, marker = 'o',label = 'Validation loss -- LSTM-CRF', markersize = 15,linewidth = 3.7)
plt.plot(epochs, val_loss2, marker = 'o', label = 'Validation loss -- BiLSTM-CRF', markersize = 16,linewidth = 3.7)
plt.plot(epochs, val_loss3, marker = 'o', label = 'Validation loss -- CNN-CRF', markersize = 16,linewidth = 3.7)

x_major_locator = MultipleLocator(1)
y_major_locator = MultipleLocator(5)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
#plt.annotate(Decimal(train_loss[19]).quantize(Decimal('0.00')), xy = (20,train_loss[19]), fontsize = 37, xytext=(19.3,train_loss[19] + 0.05))
#plt.annotate(Decimal(dev_loss[19]).quantize(Decimal('0.00')), xy = (20,dev_loss[19]), fontsize = 37, xytext=(19.3,dev_loss[19] - 0.10))
plt.tick_params(axis = 'both', which = 'major', labelsize = 29)
plt.tick_params(axis = 'x', which = 'major', labelsize = 33)
plt.xlim(0.5,20.5)
plt.ylim(0,27)

plt.title('Validation Loss', fontsize = 45)
plt.xlabel('Epochs',fontsize = 38)
plt.ylabel('Loss', fontsize = 38)
# minorticks_on()
plt.grid()
plt.legend(loc = 1, prop = {'size' : 35})
plt.show()

# %%
 # 20 epochs LSTM
val_loss1 = [0.9206,0.4801,0.3491,0.2747,0.2266,0.1938,0.1740,0.1628,0.1530,0.1454,0.1418,0.1394,0.1366,0.1395,0.1489,0.1488,0.1377,0.1268,0.1320,0.1322]
# 20 epochs BILSTM
val_loss2 = [0.8716,0.4552,0.3311,0.2640,0.2226,0.1967,0.1812,0.1711,0.1653,0.1589,0.1619,0.1642,0.1646,0.1564,0.1562,0.1656,0.1648,0.1569,0.1656,0.1586]
# 20 epochs CNN
val_loss3 = [0.6789,0.4498,0.3547,0.3057,0.2699,0.2567,0.2500,0.2385,0.2375,0.2335,0.2352,0.2328,0.2360,0.2297,0.2280,0.2293,0.2271,0.2263,0.2296,0.2293]


import matplotlib.pyplot as plt
from pylab import *
from decimal import Decimal 
epochs = range(1, len(val_loss1) + 1)

plt.figure(figsize=(24,21))
plt.plot(epochs, val_loss1, marker = 'o',label = 'Validation loss -- LSTM', markersize = 15,linewidth = 3.7)
plt.plot(epochs, val_loss2, marker = 'o', label = 'Validation loss -- BiLSTM', markersize = 16,linewidth = 3.7)
plt.plot(epochs, val_loss3, marker = 'o', label = 'Validation loss -- CNN', markersize = 16,linewidth = 3.7)

x_major_locator = MultipleLocator(1)
y_major_locator = MultipleLocator(0.25)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
#plt.annotate(Decimal(train_loss[19]).quantize(Decimal('0.00')), xy = (20,train_loss[19]), fontsize = 37, xytext=(19.3,train_loss[19] + 0.05))
#plt.annotate(Decimal(dev_loss[19]).quantize(Decimal('0.00')), xy = (20,dev_loss[19]), fontsize = 37, xytext=(19.3,dev_loss[19] - 0.10))
plt.tick_params(axis = 'both', which = 'major', labelsize = 29)
plt.tick_params(axis = 'x', which = 'major', labelsize = 33)
plt.xlim(0.5,20.5)
plt.ylim(0,1)

plt.title('Validation Loss', fontsize = 45)
plt.xlabel('Epochs',fontsize = 38)
plt.ylabel('Loss', fontsize = 38)
# minorticks_on()
plt.grid()
plt.legend(loc = 1, prop = {'size' : 35})
plt.show()

# %% [markdown]
# # 4 BiLSTM+CRF / CNN+CRF是否使用预训练词向量（默认不使用）

# %% [markdown]
# 分别在**使用预训练词向量 和 不使用预训练词向量** 情况下进行**NER**任务，对比实验结果

# %% [markdown]
# ## 4.1 python main.py --model lstm --crf --use_w2v

# %%
# 20 epochs
val_loss = [27.9406,17.8123,11.6245,8.1294,6.0916,5.0883,4.5685,4.3070,4.1744,3.9882,3.8793,3.9117,3.9004,3.8868,4.2356,3.7915,3.8325,3.7954,3.8665,3.9212]

# %%
训练完毕,共用时697秒.
评估lstm+CRF+w2v模型中...
           precision    recall  f1-score   support
  B-TITLE     0.9339    0.9326    0.9332       772
  E-TITLE     0.9794    0.9858    0.9826       772
    E-ORG     0.9322    0.9204    0.9263       553
   E-NAME     0.9905    0.9286    0.9585       112
    M-ORG     0.9631    0.9651    0.9641      4325
        O     0.9654    0.9805    0.9729      5897
  M-TITLE     0.9446    0.9043    0.9240      1922
   B-NAME     0.9694    0.8482    0.9048       112
    B-ORG     0.9690    0.9620    0.9655       553
   M-NAME     0.8681    0.9634    0.9133        82
label_level     0.9598    0.9599    0.9597     15100
    TITLE     0.9420    0.9262    0.9340       772
      ORG     0.9361    0.9005    0.9180       553
     NAME     1.0000    0.8393    0.9126       112
  all_ent     0.9437    0.9095    0.9263      1437

# %% [markdown]
# ## 4.2 python main.py --model bilstm --crf --use_w2v

# %%
# 20 epochs
val_loss = [28.6342,18.7649,12.9296,9.2585,7.1517,5.8143,5.0931,4.7167,4.5313,4.4304,4.3168,4.2417,4.2495,4.2283,4.1876,4.0183,3.9227,3.9044,3.9140,4.0422]

# %%
训练完毕,共用时670秒.
评估bilstm+CRF+w2v模型中...
           precision    recall  f1-score   support
  M-TITLE     0.9626    0.8850    0.9222      1922
    B-ORG     0.9520    0.9675    0.9596       553
  B-TITLE     0.9358    0.9249    0.9303       772
    E-ORG     0.9227    0.9060    0.9142       553
        O     0.9626    0.9744    0.9685      5897
   M-NAME     0.9610    0.9024    0.9308        82
    M-ORG     0.9413    0.9676    0.9543      4325
   B-NAME     0.9897    0.8571    0.9187       112
  E-TITLE     0.9845    0.9858    0.9851       772
   E-NAME     0.9903    0.9107    0.9488       112
label_level     0.9548    0.9546    0.9544     15100
     NAME     0.9794    0.8482    0.9091       112
      ORG     0.9211    0.8861    0.9032       553
    TITLE     0.9415    0.9171    0.9291       772
  all_ent     0.9363    0.8998    0.9177      1437

# %% [markdown]
# ## 4.3 python main.py --model cnn --crf --use_w2v

# %%
# 20 epochs
val_loss = [26.2041,17.1884,11.8955,9.3478,8.1811,7.4994,7.1777,6.8999,6.7272,6.5821,6.4515,6.3260,6.2118,6.1689,6.0183,5.9938,5.9123,5.8417,5.7486,5.6692]

# %%
训练完毕,共用时201秒.
评估cnn+CRF+w2v模型中...
           precision    recall  f1-score   support
  E-TITLE     0.9871    0.9922    0.9897       772
   B-NAME     0.8750    0.8750    0.8750       112
  M-TITLE     0.9255    0.8855    0.9051      1922
        O     0.9488    0.9515    0.9501      5897
    E-ORG     0.8583    0.9204    0.8883       553
  B-TITLE     0.9032    0.9184    0.9107       772
   E-NAME     0.9904    0.9196    0.9537       112
   M-NAME     0.8795    0.8902    0.8848        82
    M-ORG     0.9328    0.9369    0.9348      4325
    B-ORG     0.9345    0.9295    0.9320       553
label_level     0.9364    0.9362    0.9362     15100
     NAME     0.9592    0.8393    0.8952       112
    TITLE     0.9439    0.8938    0.9182       772
      ORG     0.8770    0.7866    0.8294       553
  all_ent     0.9200    0.8483    0.8827      1437

# %% [markdown]
# # 5 修改channel

# %% [markdown]
# ## python main.py --model cnn --crf

# %% [markdown]
# # hidden size = 100

# %% [markdown]
# ## Layers，3

# %%
训练完毕,共用时216秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
    E-ORG     0.9055    0.9186    0.9120       553
        O     0.9491    0.9495    0.9493      5897
  M-TITLE     0.9233    0.8959    0.9094      1922
  E-TITLE     0.9883    0.9883    0.9883       772
   M-NAME     0.9146    0.9146    0.9146        82
  B-TITLE     0.9168    0.9275    0.9221       772
    M-ORG     0.9342    0.9447    0.9394      4325
   E-NAME     0.9712    0.9018    0.9352       112
   B-NAME     0.8585    0.8125    0.8349       112
    B-ORG     0.9263    0.9313    0.9288       553
label_level   0.9388    0.9388    0.9387     15100
      ORG     0.9177    0.8065    0.8585       553
    TITLE     0.9562    0.9054    0.9301       772
     NAME     1.0000    0.8036    0.8911       112
  all_ent     0.9449    0.8594    0.9001      1437

# %%
val_loss1 = [19.2337,13.3491,10.8365,9.3406,8.3632,7.6292,7.1524,6.8019,6.4870,
6.2254,6.0007,5.8531,5.6110,5.5131,5.3536,5.2125,5.1339,5.0556,4.9228,4.8129]

# %% [markdown]
# ## Layers，5

# %%
Epoch 20, Val Loss:4.4880
训练完毕,共用时202秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
    B-ORG     0.9408    0.9476    0.9441       553
  E-TITLE     0.9807    0.9896    0.9852       772
   B-NAME     1.0000    0.9643    0.9818       112
  M-TITLE     0.9208    0.9131    0.9169      1922
  B-TITLE     0.9024    0.9339    0.9179       772
   M-NAME     0.9412    0.9756    0.9581        82
        O     0.9682    0.9552    0.9617      5897
    E-ORG     0.8998    0.9259    0.9127       553
    M-ORG     0.9414    0.9510    0.9462      4325
   E-NAME     0.9727    0.9554    0.9640       112
label_level   0.9484    0.9481    0.9482     15100
    TITLE     0.9445    0.9262    0.9353       772
      ORG     0.9017    0.8463    0.8731       553
     NAME     0.9907    0.9464    0.9680       112
  all_ent     0.9320    0.8970    0.9142      1437

# %%
val_loss2 = [6.8588,10.5084,8.4521,7.4728,6.7926,6.4122,6.0731,5.8484,
            5.7037,5.5244,5.3100,5.1433,5.1469,5.0811,4.9217,4.9465,
            4.9101,4.9887,4.7474,4.7531]

# %% [markdown]
# ## Layers, 7

# %%
Epoch 20, Val Loss:4.8531
训练完毕,共用时217秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
    B-ORG     0.9514    0.9566    0.9540       553
  B-TITLE     0.9182    0.9301    0.9241       772
   E-NAME     1.0000    0.9643    0.9818       112
    E-ORG     0.9152    0.9168    0.9160       553
  E-TITLE     0.9820    0.9883    0.9852       772
    M-ORG     0.9422    0.9686    0.9552      4325
   M-NAME     0.9091    0.9756    0.9412        82
   B-NAME     1.0000    0.9554    0.9772       112
  M-TITLE     0.9274    0.8902    0.9084      1922
        O     0.9702    0.9603    0.9652      5897
label_level   0.9521    0.9520    0.9519     15100
      ORG     0.9461    0.8879    0.9160       553
     NAME     1.0000    0.9464    0.9725       112
    TITLE     0.9360    0.9093    0.9225       772
  all_ent     0.9447    0.9040    0.9239      1437

# %%
val_loss3 = [14.8701,9.1095,7.3410,6.4803,5.9518,5.5111,5.2541,
            5.0234,4.9053,4.7352,4.7190,4.6747,4.5596,4.4628,
            4.4847,4.2873,4.4170,4.3812,4.2685,4.3515]

# %% [markdown]
# ## Layers, 9

# %%
训练完毕,共用时239秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
   E-NAME     0.9907    0.9554    0.9727       112
  M-TITLE     0.9258    0.8897    0.9074      1922
    B-ORG     0.9631    0.9439    0.9534       553
   B-NAME     1.0000    0.9554    0.9772       112
   M-NAME     1.0000    0.9756    0.9877        82
  E-TITLE     0.9895    0.9767    0.9831       772
    E-ORG     0.9168    0.9168    0.9168       553
        O     0.9598    0.9705    0.9651      5897
    M-ORG     0.9508    0.9598    0.9552      4325
  B-TITLE     0.9262    0.9262    0.9262       772
label_level   0.9520    0.9521    0.9519     15100
      ORG     0.9306    0.8734    0.9011       553
    TITLE     0.9499    0.9093    0.9292       772
     NAME     1.0000    0.9554    0.9772       112
  all_ent     0.9465    0.8991    0.9222      1437

# %%
val_loss4 = [16.8334,9.1869,7.1355,6.2536,5.5954,5.1705,4.9495,
            4.6918,4.5087,4.5314,4.3382,4.4875,4.4687,4.5390,
            4.4236,4.6324,4.5990,4.5656,4.6196,4.6563]

# %% [markdown]
# ## Layers, 11

# %%
Epoch 20, Val Loss:5.1799
训练完毕,共用时243秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
    B-ORG     0.9510    0.9476    0.9493       553
   M-NAME     1.0000    0.9390    0.9686        82
    E-ORG     0.9159    0.9060    0.9109       553
  E-TITLE     0.9896    0.9858    0.9877       772
    M-ORG     0.9527    0.9602    0.9565      4325
  B-TITLE     0.9221    0.9197    0.9209       772
   B-NAME     1.0000    0.9196    0.9581       112
        O     0.9645    0.9708    0.9676      5897
  M-TITLE     0.9256    0.9063    0.9159      1922
   E-NAME     1.0000    0.9464    0.9725       112
label_level   0.9537    0.9538    0.9537     15100
     NAME     1.0000    0.9196    0.9581       112
      ORG     0.9120    0.8626    0.8866       553
    TITLE     0.9512    0.9080    0.9291       772
  all_ent     0.9398    0.8914    0.9150      1437

# %%
val_loss5 = [16.6085,8.9636,6.8415,5.9630,5.4347,5.1526,4.9363,
            4.8716,4.6715,4.6744,4.5600,4.5511,4.5441,4.7401,
            4.6389,4.5979,4.7846,4.9283,4.9141,4.7075]

# %%
val_loss1 = [19.2337,13.3491,10.8365,9.3406,8.3632,7.6292,7.1524,6.8019,6.4870,
6.2254,6.0007,5.8531,5.6110,5.5131,5.3536,5.2125,5.1339,5.0556,4.9228,4.8129]
val_loss2 = [6.8588,10.5084,8.4521,7.4728,6.7926,6.4122,6.0731,5.8484,
            5.7037,5.5244,5.3100,5.1433,5.1469,5.0811,4.9217,4.9465,
            4.9101,4.9887,4.7474,4.7531]
val_loss3 = [14.8701,9.1095,7.3410,6.4803,5.9518,5.5111,5.2541,
            5.0234,4.9053,4.7352,4.7190,4.6747,4.5596,4.4628,
            4.4847,4.2873,4.4170,4.3812,4.2685,4.3515]
val_loss4 = [16.8334,9.1869,7.1355,6.2536,5.5954,5.1705,4.9495,
            4.6918,4.5087,4.5314,4.3382,4.4875,4.4687,4.5390,
            4.4236,4.6324,4.5990,4.5656,4.6196,4.6563]
val_loss5 = [16.6085,8.9636,6.8415,5.9630,5.4347,5.1526,4.9363,
            4.8716,4.6715,4.6744,4.5600,4.5511,4.5441,4.7401,
            4.6389,4.5979,4.7846,4.9283,4.9141,4.7075]

from decimal import Decimal 
epochs = range(1, len(val_loss1) + 1)
plt.figure(figsize = (25,23))
x_major_locator = MultipleLocator(1)
y_major_locator = MultipleLocator(5)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)

plt.tick_params(axis = 'both', which = 'major', labelsize = 32)
plt.tick_params(axis = 'x', which = 'major', labelsize = 33)
plt.xlim(0.5,20.5)
plt.ylim(0,22)

x = range(1,21)
plt.title("CNN - Kernel size - validation loss ",fontsize = 45)
plt.xlabel("Epochs",fontsize = 30)
plt.ylabel("Loss",fontsize = 30)

# plt.plot(x, lr1,marker = 'o',color ='#bc13fe',label = '1',markersize = 12)
# plt.plot(x, lr2,marker = 'o',color ='r',label = '2',markersize = 12)
plt.plot(x, val_loss1, marker = 'o',label = 'kernel size = 3',markersize = 15,linewidth = 4)
plt.plot(x, val_loss2, marker = 'o',label = 'kernel size = 5',markersize = 15,linewidth = 4)
plt.plot(x, val_loss3, marker = 'o',label = 'kernel size = 7',markersize = 15,linewidth = 4)
plt.plot(x, val_loss4, marker = 'o',label = 'kernel size = 9',markersize = 15,linewidth = 4)
plt.plot(x, val_loss5 ,marker = 'o',label = 'kernel size = 11',markersize = 15,linewidth = 4)

plt.legend(loc = 5, prop = {'size' : 35})
plt.grid()
plt.show()

# %% [markdown]
# # Hidden size = 100，layers = 7

# %%
Epoch 20, Val Loss:4.8531
训练完毕,共用时217秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
    B-ORG     0.9514    0.9566    0.9540       553
  B-TITLE     0.9182    0.9301    0.9241       772
   E-NAME     1.0000    0.9643    0.9818       112
    E-ORG     0.9152    0.9168    0.9160       553
  E-TITLE     0.9820    0.9883    0.9852       772
    M-ORG     0.9422    0.9686    0.9552      4325
   M-NAME     0.9091    0.9756    0.9412        82
   B-NAME     1.0000    0.9554    0.9772       112
  M-TITLE     0.9274    0.8902    0.9084      1922
        O     0.9702    0.9603    0.9652      5897
label_level     0.9521    0.9520    0.9519     15100
      ORG     0.9461    0.8879    0.9160       553
     NAME     1.0000    0.9464    0.9725       112
    TITLE     0.9360    0.9093    0.9225       772
  all_ent     0.9447    0.9040    0.9239      1437

# %%
val_loss1 = [14.8701,9.1095,7.3410,6.4803,5.9518,5.5111,5.2541,
            5.0234,4.9053,4.7352,4.7190,4.6747,4.5596,4.4628,
            4.4847,4.2873,4.4170,4.3812,4.2685,4.3515]

# %% [markdown]
# # Hidden size = 200，layers = 7

# %%
Epoch 20, Val Loss:5.4658
训练完毕,共用时301秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
    M-ORG     0.9393    0.9623    0.9507      4325
    B-ORG     0.9344    0.9277    0.9310       553
    E-ORG     0.9167    0.8951    0.9058       553
   B-NAME     0.9910    0.9821    0.9865       112
   E-NAME     0.9825    1.0000    0.9912       112
  E-TITLE     0.9857    0.9832    0.9844       772
   M-NAME     0.8989    0.9756    0.9357        82
        O     0.9662    0.9651    0.9656      5897
  M-TITLE     0.9275    0.8850    0.9058      1922
  B-TITLE     0.9210    0.9210    0.9210       772
label_level     0.9492    0.9493    0.9491     15100
    TITLE     0.9500    0.9106    0.9299       772
      ORG     0.9212    0.8246    0.8702       553
     NAME     0.9821    0.9821    0.9821       112
  all_ent     0.9421    0.8831    0.9116      1437

# %%
val_loss2 = [13.6389,8.5838,7.1205,6.4203,6.0158,5.6679,5.6305,
            5.4523,5.4445,5.3846,5.2354,5.1359,5.2208,5.2899,
            5.2468,5.5162,5.5842,5.7336,5.8818,5.8771]

# %% [markdown]
# # Hidden size = 300，layers = 7

# %%
训练完毕,共用时406秒.
评估cnn+CRF模型中...
           precision    recall  f1-score   support
   E-NAME     0.9908    0.9643    0.9774       112
   M-NAME     0.9639    0.9756    0.9697        82
   B-NAME     1.0000    0.9821    0.9910       112
  M-TITLE     0.9232    0.8881    0.9053      1922
    B-ORG     0.9540    0.9367    0.9453       553
    E-ORG     0.9224    0.9024    0.9122       553
  E-TITLE     0.9908    0.9793    0.9850       772
        O     0.9626    0.9642    0.9634      5897
    M-ORG     0.9394    0.9614    0.9503      4325
  B-TITLE     0.9259    0.9223    0.9241       772
label_level     0.9492    0.9493    0.9492     15100
    TITLE     0.9574    0.9028    0.9293       772
     NAME     1.0000    0.9643    0.9818       112
      ORG     0.9328    0.8535    0.8914       553
  all_ent     0.9516    0.8887    0.9190      1437

# %%
val_loss3 = [12.2194,8.2262,6.8013,6.1318,5.6935,5.5688,5.3387,
            5.3512,5.3394,5.3877,5.2893,5.8110,5.7653,5.8568,
            5.9507,6.3340,6.9465,6.4630,6.2046,7.0720]

# %%
val_loss1 = [14.8701,9.1095,7.3410,6.4803,5.9518,5.5111,5.2541,
            5.0234,4.9053,4.7352,4.7190,4.6747,4.5596,4.4628,
            4.4847,4.2873,4.4170,4.3812,4.2685,4.3515]
val_loss2 = [13.6389,8.5838,7.1205,6.4203,6.0158,5.6679,5.6305,
            5.4523,5.4445,5.3846,5.2354,5.1359,5.2208,5.2899,
            5.2468,5.5162,5.5842,5.7336,5.8818,5.8771]

val_loss3 = [12.2194,8.2262,6.8013,6.1318,5.6935,5.5688,5.3387,
            5.3512,5.3394,5.3877,5.2893,5.8110,5.7653,5.8568,
            5.9507,6.3340,6.9465,6.4630,6.2046,7.0720]


from decimal import Decimal 
epochs = range(1, len(val_loss1) + 1)
plt.figure(figsize = (25,20))
x_major_locator = MultipleLocator(1)
y_major_locator = MultipleLocator(5)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)

plt.tick_params(axis = 'both', which = 'major', labelsize = 32)
plt.tick_params(axis = 'x', which = 'major', labelsize = 33)
plt.xlim(0.5,20.5)
plt.ylim(0,16)

x = range(1,21)
plt.title("CNN - Hidden size - validation loss ",fontsize = 45)
plt.xlabel("Epochs",fontsize = 30)
plt.ylabel("Loss",fontsize = 30)

# plt.plot(x, lr1,marker = 'o',color ='#bc13fe',label = '1',markersize = 12)
# plt.plot(x, lr2,marker = 'o',color ='r',label = '2',markersize = 12)
#plt.plot(x, val_loss1, marker = 'o',label = 'kernel size = 3',markersize = 15,linewidth = 4)
#plt.plot(x, val_loss2, marker = 'o',label = 'kernel size = 5',markersize = 15,linewidth = 4)
plt.plot(x, val_loss1, marker = 'o',label = 'hidden size = 100',markersize = 15,linewidth = 4)
plt.plot(x, val_loss2, marker = 'o',label = 'hidden size = 200',markersize = 15,linewidth = 4)
plt.plot(x, val_loss3 ,marker = 'o',label = 'hidden size = 300',markersize = 15,linewidth = 4)

plt.legend(loc = 1, prop = {'size' : 35})
plt.grid()
plt.show()

# %% [markdown]
# # 模型训练参数：

# %% [markdown]
# ![image.png](attachment:image.png)
